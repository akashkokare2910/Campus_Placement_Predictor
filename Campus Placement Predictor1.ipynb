# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
df = pd.read_csv('/content/drive/MyDrive/Campus Placement Pred/Placement_Data.csv')
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  ...  specialisation  mba_p      status    salary
# 0      1      M  67.00   Others  ...          Mkt&HR  58.80      Placed  270000.0
# 1      2      M  79.33  Central  ...         Mkt&Fin  66.28      Placed  200000.0
# 2      3      M  65.00  Central  ...         Mkt&Fin  57.80      Placed  250000.0
# 3      4      M  56.00  Central  ...          Mkt&HR  59.43  Not Placed       NaN
# 4      5      M  85.80  Central  ...         Mkt&Fin  55.50      Placed  425000.0
#
# [5 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
# seperating the categorical and numerical columns

categorical_vars = list(df.select_dtypes(include=['object']).columns)

numerical_vars = list(df.select_dtypes(include=['int32','int64','float32','float64']).columns)


print(categorical_vars,numerical_vars)
# Out:
# ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status'] ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
df.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# ### Handling Null values

# %%
df.shape
# Out:
# (215, 15)

# %%
  def plotdistplot(col):
    
    plt.figure(figsize=(15,7))
    sns.distplot(df['salary'],kde=True,hist=False,label='Actual Salary',color='green')
    sns.distplot(df[col],kde=True,hist=False,label=col,color='orange')

# %%
mostfreq = list(dict(df['salary'].value_counts()).items())[0]
mostfreq
# Out:
# (300000.0, 22)

# %%
df['salary'].mode()[0]
# Out:
# 300000.0

# %%
df['salary_mean'] = df['salary'].fillna(df['salary'].mean())
df['salary_median'] = df['salary'].fillna(df['salary'].median())
df['salary_mode'] = df['salary'].fillna(df['salary'].mode()[0])
df.head()
# Out:
#    sl_no gender  ssc_p  ...    salary_mean  salary_median salary_mode
# 0      1      M  67.00  ...  270000.000000       270000.0    270000.0
# 1      2      M  79.33  ...  200000.000000       200000.0    200000.0
# 2      3      M  65.00  ...  250000.000000       250000.0    250000.0
# 3      4      M  56.00  ...  288655.405405       265000.0    300000.0
# 4      5      M  85.80  ...  425000.000000       425000.0    425000.0
#
# [5 rows x 18 columns]

# %%
sallist = ['salary_mean','salary_median','salary_mode']
for sal in sallist:
    plotdistplot(sal)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# filling the salary with mean of the salary column

df['salary'] = df['salary'].fillna(df['salary'].mean())
df.head()
# Out:
#    sl_no gender  ssc_p  ...    salary_mean  salary_median salary_mode
# 0      1      M  67.00  ...  270000.000000       270000.0    270000.0
# 1      2      M  79.33  ...  200000.000000       200000.0    200000.0
# 2      3      M  65.00  ...  250000.000000       250000.0    250000.0
# 3      4      M  56.00  ...  288655.405405       265000.0    300000.0
# 4      5      M  85.80  ...  425000.000000       425000.0    425000.0
#
# [5 rows x 18 columns]

# %%
df = df.drop(columns=['salary_mean', 'salary_median', 'salary_mode'],axis=1)
df.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# ## EDA

# %%
sns.countplot(df['status'],palette='husl')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
def valuecount(col):
    
    return dict(df[col].value_counts())

def getcountplot(col):
    
    sns.countplot(df[col],palette='husl')
    plt.xticks(rotation = '30',fontweight = 'bold',fontsize = '10')
    plt.yticks(rotation = '30',fontweight = 'bold',fontsize = '10')
    plt.show()
    

for col in categorical_vars:
    print(f'Count Plot for feature {col} is shown ↓')
    getcountplot(col)
    print('='*75)
# Out:
# Count Plot for feature gender is shown ↓
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ===========================================================================
# Count Plot for feature ssc_b is shown ↓
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ===========================================================================
# Count Plot for feature hsc_b is shown ↓
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ===========================================================================
# Count Plot for feature hsc_s is shown ↓
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ===========================================================================
# Count Plot for feature degree_t is shown ↓
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ===========================================================================
# Count Plot for feature workex is shown ↓
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ===========================================================================
# Count Plot for feature specialisation is shown ↓
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ===========================================================================
# Count Plot for feature status is shown ↓
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ===========================================================================

# %%
getfinaldict = {}
for col in categorical_vars:
    getfinaldict[col] = valuecount(col)
    
getfinaldict
# Out:
# {'degree_t': {'Comm&Mgmt': 145, 'Others': 11, 'Sci&Tech': 59},
#  'gender': {'F': 76, 'M': 139},
#  'hsc_b': {'Central': 84, 'Others': 131},
#  'hsc_s': {'Arts': 11, 'Commerce': 113, 'Science': 91},
#  'specialisation': {'Mkt&Fin': 120, 'Mkt&HR': 95},
#  'ssc_b': {'Central': 116, 'Others': 99},
#  'status': {'Not Placed': 67, 'Placed': 148},
#  'workex': {'No': 141, 'Yes': 74}}

# %%
# Placed students from science stream

df[(df['degree_t']=='Sci&Tech')&(df['status']=='Placed')].sort_values(by = 'salary',ascending = False).reset_index().head(5)
# Out:
#    index  sl_no gender  ssc_p  ... specialisation  mba_p  status    salary
# 0    150    151      M  71.00  ...        Mkt&Fin  61.30  Placed  690000.0
# 1     77     78      M  64.00  ...        Mkt&Fin  57.65  Placed  500000.0
# 2    163    164      M  63.00  ...        Mkt&Fin  66.46  Placed  500000.0
# 3    174    175      M  73.24  ...        Mkt&Fin  66.23  Placed  500000.0
# 4     53     54      M  80.00  ...         Mkt&HR  71.04  Placed  450000.0
#
# [5 rows x 16 columns]

# %%
# Placed students from Commerce and Management stream

df[(df['degree_t']=='Comm&Mgmt')&(df['status']=='Placed')].sort_values(by = 'salary',ascending = False).reset_index().head(5)
# Out:
#    index  sl_no gender  ssc_p  ... specialisation  mba_p  status    salary
# 0    119    120      M   60.8  ...        Mkt&Fin  64.34  Placed  940000.0
# 1    177    178      F   73.0  ...        Mkt&Fin  70.81  Placed  650000.0
# 2      4      5      M   85.8  ...        Mkt&Fin  55.50  Placed  425000.0
# 3     95     96      M   73.0  ...        Mkt&Fin  62.16  Placed  420000.0
# 4    210    211      M   80.6  ...        Mkt&Fin  74.49  Placed  400000.0
#
# [5 rows x 16 columns]

# %%
# Placed students from Other streams
df[(df['degree_t']=='Others')&(df['status']=='Placed')].sort_values(by = 'salary',ascending = False).reset_index().head(5)
# Out:
#    index  sl_no gender  ssc_p  ... specialisation  mba_p  status    salary
# 0    131    132      F   74.9  ...        Mkt&Fin  60.78  Placed  360000.0
# 1    193    194      F   60.0  ...         Mkt&HR  56.63  Placed  300000.0
# 2    185    186      F   88.0  ...         Mkt&HR  71.43  Placed  252000.0
# 3    124    125      M   67.0  ...         Mkt&HR  61.26  Placed  250000.0
# 4    148    149      F   77.0  ...        Mkt&Fin  64.08  Placed  240000.0
#
# [5 rows x 16 columns]

# %%
# maximum and minimum salary
# observation : max salary : 9,40,000 and min salary : 2,00,000

df[(df['salary']==max(df['salary'])) | (df['salary']==min(df['salary']))].sort_values(by='salary', ascending=False)
# Out:
#      sl_no gender  ssc_p    ssc_b  ...  specialisation  mba_p  status    salary
# 119    120      M  60.80  Central  ...         Mkt&Fin  64.34  Placed  940000.0
# 1        2      M  79.33  Central  ...         Mkt&Fin  66.28  Placed  200000.0
# 15      16      F  65.00  Central  ...         Mkt&Fin  64.66  Placed  200000.0
# 44      45      F  77.00   Others  ...         Mkt&Fin  69.70  Placed  200000.0
# 50      51      F  75.20  Central  ...          Mkt&HR  62.98  Placed  200000.0
# 107    108      M  82.00   Others  ...          Mkt&HR  73.52  Placed  200000.0
# 135    136      F  72.00  Central  ...          Mkt&HR  65.63  Placed  200000.0
#
# [7 rows x 15 columns]

# %%
# students with salary more than avg salary are from science 

df[(df['degree_t']=='Sci&Tech')&(df['salary']>df['salary'].mean())].sort_values(by = 'salary',ascending = False).reset_index().head(10)
# Out:
#    index  sl_no gender  ssc_p  ... specialisation  mba_p  status    salary
# 0    150    151      M  71.00  ...        Mkt&Fin  61.30  Placed  690000.0
# 1     77     78      M  64.00  ...        Mkt&Fin  57.65  Placed  500000.0
# 2    174    175      M  73.24  ...        Mkt&Fin  66.23  Placed  500000.0
# 3    163    164      M  63.00  ...        Mkt&Fin  66.46  Placed  500000.0
# 4     53     54      M  80.00  ...         Mkt&HR  71.04  Placed  450000.0
# 5     39     40      M  81.00  ...        Mkt&Fin  62.56  Placed  411000.0
# 6    145    146      M  89.40  ...         Mkt&HR  63.23  Placed  400000.0
# 7    128    129      M  80.40  ...         Mkt&HR  76.26  Placed  400000.0
# 8     22     23      F  69.80  ...         Mkt&HR  68.81  Placed  360000.0
# 9     24     25      M  76.50  ...        Mkt&Fin  74.01  Placed  360000.0
#
# [10 rows x 16 columns]

# %%
# Students with salary more than avg salary Commerce and Management dept

df[(df['degree_t']=='Comm&Mgmt')&(df['salary']>df['salary'].mean())].sort_values(by = 'salary',ascending = False).reset_index()
# Out:
#     index  sl_no gender  ssc_p  ... specialisation  mba_p      status         salary
# 0     119    120      M   60.8  ...        Mkt&Fin  64.34      Placed  940000.000000
# 1     177    178      F   73.0  ...        Mkt&Fin  70.81      Placed  650000.000000
# 2       4      5      M   85.8  ...        Mkt&Fin  55.50      Placed  425000.000000
# 3      95     96      M   73.0  ...        Mkt&Fin  62.16      Placed  420000.000000
# 4     210    211      M   80.6  ...        Mkt&Fin  74.49      Placed  400000.000000
# ..    ...    ...    ...    ...  ...            ...    ...         ...            ...
# 70    120    121      M   58.0  ...         Mkt&HR  58.81  Not Placed  288655.405405
# 71     29     30      M   62.0  ...        Mkt&Fin  51.29  Not Placed  288655.405405
# 72     36     37      M   51.0  ...        Mkt&Fin  51.45  Not Placed  288655.405405
# 73    136    137      F   47.0  ...        Mkt&Fin  61.58  Not Placed  288655.405405
# 74    214    215      M   62.0  ...         Mkt&HR  60.22  Not Placed  288655.405405
#
# [75 rows x 16 columns]

# %%
# maximum students placed are from comm&mgt

df.groupby(['degree_t'])['status'].count().plot(kind = 'bar',color = 'c')

# %%
# Marketing and Finance specialisation are placed more

df.groupby(['specialisation'])['status'].count().plot(kind = 'bar',color = 'g')

# %%
df.groupby(['gender'])['status'].count().plot(kind = 'pie',autopct='%1.0f%%')

# %% [markdown]
# ###Con: Placed Females are 35% and Males are 65%

# %%
temp = df[df['gender']=='F']
temp[temp['salary']==max(temp['salary'])].style.background_gradient(cmap = 'YlOrRd')
# Out:
# <style  type="text/css" >
# #T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col0,#T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col2,#T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col4,#T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col7,#T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col10,#T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col12,#T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col14{
#             background-color:  #ffffcc;
#             color:  #000000;
#         }</style><table id="T_3767585c_3e30_11ec_940e_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sl_no</th>        <th class="col_heading level0 col1" >gender</th>        <th class="col_heading level0 col2" >ssc_p</th>        <th class="col_heading level0 col3" >ssc_b</th>        <th class="col_heading level0 col4" >hsc_p</th>        <th class="col_heading level0 col5" >hsc_b</th>        <th class="col_heading level0 col6" >hsc_s</th>        <th class="col_heading level0 col7" >degree_p</th>        <th class="col_heading level0 col8" >degree_t</th>        <th class="col_heading level0 col9" >workex</th>        <th class="col_heading level0 col10" >etest_p</th>        <th class="col_heading level0 col11" >specialisation</th>        <th class="col_heading level0 col12" >mba_p</th>        <th class="col_heading level0 col13" >status</th>        <th class="col_heading level0 col14" >salary</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3767585c_3e30_11ec_940e_0242ac1c0002level0_row0" class="row_heading level0 row0" >177</th>
#                         <td id="T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col0" class="data row0 col0" >178</td>
#                         <td id="T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col1" class="data row0 col1" >F</td>
#                         <td id="T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col2" class="data row0 col2" >73.000000</td>
#                         <td id="T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col3" class="data row0 col3" >Central</td>
#                         <td id="T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col4" class="data row0 col4" >97.000000</td>
#                         <td id="T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col5" class="data row0 col5" >Others</td>
#                         <td id="T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col6" class="data row0 col6" >Commerce</td>
#                         <td id="T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col7" class="data row0 col7" >79.000000</td>
#                         <td id="T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col8" class="data row0 col8" >Comm&Mgmt</td>
#                         <td id="T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col9" class="data row0 col9" >Yes</td>
#                         <td id="T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col10" class="data row0 col10" >89.000000</td>
#                         <td id="T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col11" class="data row0 col11" >Mkt&Fin</td>
#                         <td id="T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col12" class="data row0 col12" >70.810000</td>
#                         <td id="T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col13" class="data row0 col13" >Placed</td>
#                         <td id="T_3767585c_3e30_11ec_940e_0242ac1c0002row0_col14" class="data row0 col14" >650000.000000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Max Salary of Female Category = 65000

# %%
df.groupby(['hsc_s'])['status'].count().plot(kind = 'pie',autopct='%1.0f%%',figsize=(15,7))

# %%
df.head()
# Out:
#    sl_no gender  ssc_p  ...  mba_p      status         salary
# 0      1      M  67.00  ...  58.80      Placed  270000.000000
# 1      2      M  79.33  ...  66.28      Placed  200000.000000
# 2      3      M  65.00  ...  57.80      Placed  250000.000000
# 3      4      M  56.00  ...  59.43  Not Placed  288655.405405
# 4      5      M  85.80  ...  55.50      Placed  425000.000000
#
# [5 rows x 15 columns]

# %%
getfinaldict
# Out:
# {'degree_t': {'Comm&Mgmt': 145, 'Others': 11, 'Sci&Tech': 59},
#  'gender': {'F': 76, 'M': 139},
#  'hsc_b': {'Central': 84, 'Others': 131},
#  'hsc_s': {'Arts': 11, 'Commerce': 113, 'Science': 91},
#  'specialisation': {'Mkt&Fin': 120, 'Mkt&HR': 95},
#  'ssc_b': {'Central': 116, 'Others': 99},
#  'status': {'Not Placed': 67, 'Placed': 148},
#  'workex': {'No': 141, 'Yes': 74}}

# %%
len(getfinaldict['status']),len(getfinaldict['degree_t'])
# Out:
# (2, 3)

# %%
boolcols = [key for key,value in getfinaldict.items() if len(getfinaldict[key])==2]
tripcols = [key for key in list(getfinaldict.keys()) if key not in boolcols]

print(boolcols,tripcols)
# Out:
# ['gender', 'ssc_b', 'hsc_b', 'workex', 'specialisation', 'status'] ['hsc_s', 'degree_t']

# %% [markdown]
# ## Label Encoding process

# %%
def labelencode(le,col):
    
    df[col] = le.fit_transform(df[col])
    
    
getmappings = {}
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in list(getfinaldict.keys()):
    labelencode(le,col)
    getmappings[col] = dict(zip(le.classes_,le.transform(le.classes_)))
    

df.head()
# Out:
#    sl_no  gender  ssc_p  ssc_b  ...  specialisation  mba_p  status         salary
# 0      1       1  67.00      1  ...               1  58.80       1  270000.000000
# 1      2       1  79.33      0  ...               0  66.28       1  200000.000000
# 2      3       1  65.00      0  ...               0  57.80       1  250000.000000
# 3      4       1  56.00      0  ...               1  59.43       0  288655.405405
# 4      5       1  85.80      0  ...               0  55.50       1  425000.000000
#
# [5 rows x 15 columns]

# %%
# this was the internal mapping structure followed by label encoder for mapping

getmappings
# Out:
# {'degree_t': {'Comm&Mgmt': 0, 'Others': 1, 'Sci&Tech': 2},
#  'gender': {'F': 0, 'M': 1},
#  'hsc_b': {'Central': 0, 'Others': 1},
#  'hsc_s': {'Arts': 0, 'Commerce': 1, 'Science': 2},
#  'specialisation': {'Mkt&Fin': 0, 'Mkt&HR': 1},
#  'ssc_b': {'Central': 0, 'Others': 1},
#  'status': {'Not Placed': 0, 'Placed': 1},
#  'workex': {'No': 0, 'Yes': 1}}

# %%
# removing unwated columns

df = df.drop(['sl_no'],axis=1)
df.head(2)
# Out:
#    gender  ssc_p  ssc_b  hsc_p  ...  specialisation  mba_p  status    salary
# 0       1  67.00      1  91.00  ...               1  58.80       1  270000.0
# 1       1  79.33      0  78.33  ...               0  66.28       1  200000.0
#
# [2 rows x 14 columns]

# %% [markdown]
# ## Numerical Columns EDA

# %%
numerical_vars[1:]
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
import scipy.stats as stats

def getplots(df,col):
    
    plt.figure(figsize=(15,7))
    plt.subplot(1,3,1)
    plt.hist(df[col],color='magenta')
    
    plt.subplot(1,3,2)
    stats.probplot(df[col],dist='norm',plot=plt)
    
    plt.subplot(1,3,3)
    sns.boxplot(df[col],color='magenta')
    
    plt.show()
    
    
for col in numerical_vars[1:]:
    print(f'Distribution plots for col : {col} are shown ↓')
    getplots(df,col)
    print('='*10)
# Out:
# Distribution plots for col : ssc_p are shown ↓
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ==========
# Distribution plots for col : hsc_p are shown ↓
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ==========
# Distribution plots for col : degree_p are shown ↓
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ==========
# Distribution plots for col : etest_p are shown ↓
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ==========
# Distribution plots for col : mba_p are shown ↓
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ==========
# Distribution plots for col : salary are shown ↓
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ==========

# %% [markdown]
# # Feature Selection

# %%
# checking for tightly correlated features

plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,cmap='plasma')

# %%
# We will drop the salary column as well
# Beacause after getting the placement we will get to know the salary or the roles!

data = df.copy()
test = data['status']
train = data.drop(['status','salary'],axis = 1)
train.head(2)
# Out:
#    gender  ssc_p  ssc_b  hsc_p  ...  workex  etest_p  specialisation  mba_p
# 0       1  67.00      1  91.00  ...       0     55.0               1  58.80
# 1       1  79.33      0  78.33  ...       1     86.5               0  66.28
#
# [2 rows x 12 columns]

# %%
## extratrees classifier

from sklearn.ensemble import ExtraTreesClassifier
ec = ExtraTreesClassifier()
ec.fit(train,test)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100,
#                      n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
featbar = pd.Series(ec.feature_importances_,index=train.columns)
featbar.nlargest(7).plot(kind = 'barh')

# %%
featbar.nlargest(7).plot(kind='pie',autopct='%1.0f%%',figsize = (15,7))

# %%
# mutual classif

from sklearn.feature_selection import mutual_info_classif
mc = mutual_info_classif(train,test)
ax = pd.Series(mc,index=train.columns)
ax.nlargest(7).plot(kind = 'barh')

# %%
pd.Series(mc,index=train.columns).plot(kind = 'pie',autopct='%1.0f%%',figsize = (15,7))

# %%
# Selecting the top 10 contributing features in both cases
# and then we will do the intersection of both the results
# so that we will get atleast top 5 most contributing features!


featcol = list(featbar.nlargest(10).index)
mutclasif = list(ax.nlargest(10).index)
commoncols = list(set(featcol).intersection(set(mutclasif)))
print(commoncols)
# Out:
# ['ssc_b', 'gender', 'specialisation', 'mba_p', 'workex', 'degree_p', 'degree_t', 'ssc_p', 'hsc_p']

# %%
# selecting the common cols and will do training on these cols!
# these cols were selected as a nlargest result of 2 feature selection techniques!

train = df[commoncols]
train.head()
# Out:
#    ssc_b  gender  specialisation  mba_p  ...  degree_p  degree_t  ssc_p  hsc_p
# 0      1       1               1  58.80  ...     58.00         2  67.00  91.00
# 1      0       1               0  66.28  ...     77.48         2  79.33  78.33
# 2      0       1               0  57.80  ...     64.00         0  65.00  68.00
# 3      0       1               1  59.43  ...     52.00         2  56.00  52.00
# 4      0       1               0  55.50  ...     73.30         0  85.80  73.60
#
# [5 rows x 9 columns]

# %%
# From the above DF we notice that gender,specialisation,degree_t,workex are the 
# categorical columns and they make sense isn't it?,for any placement drive
# students are first filtered on basis of their boards,sem scores which in this case are {mba_p,ssc_p,degree_p,hsc_p}
# and then workexperience also matters a lot!,then specialisation as well,gender is also important
# because now-a-days few companies focus on women empowerment,so yes,all the features make perfect sense!


getmappings
# Out:
# {'degree_t': {'Comm&Mgmt': 0, 'Others': 1, 'Sci&Tech': 2},
#  'gender': {'F': 0, 'M': 1},
#  'hsc_b': {'Central': 0, 'Others': 1},
#  'hsc_s': {'Arts': 0, 'Commerce': 1, 'Science': 2},
#  'specialisation': {'Mkt&Fin': 0, 'Mkt&HR': 1},
#  'ssc_b': {'Central': 0, 'Others': 1},
#  'status': {'Not Placed': 0, 'Placed': 1},
#  'workex': {'No': 0, 'Yes': 1}}

# %%
# renaming the cols

train = train[['degree_t','gender','specialisation','workex','ssc_p','hsc_p','degree_p','mba_p']]
train.columns = ['Techinal Degree','Gender','Specialisation','Work Experience','SSC_p','High School_p','Degree_p','MBA_p']
train.head()
# Out:
#    Techinal Degree  Gender  Specialisation  ...  High School_p  Degree_p  MBA_p
# 0                2       1               1  ...          91.00     58.00  58.80
# 1                2       1               0  ...          78.33     77.48  66.28
# 2                0       1               0  ...          68.00     64.00  57.80
# 3                2       1               1  ...          52.00     52.00  59.43
# 4                0       1               0  ...          73.60     73.30  55.50
#
# [5 rows x 8 columns]

# %%
train['Techinal Degree'].value_counts()
# Out:
# 0    145
# 2     59
# 1     11
# Name: Techinal Degree, dtype: int64

# %% [markdown]
# ## Model Building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split,RandomizedSearchCV,cross_val_score
from sklearn import metrics

# %%
X_train, X_test, y_train, y_test = train_test_split(train,test,test_size=0.2)
X_train.shape,X_test.shape
# Out:
# ((172, 8), (43, 8))

# %%
dc = DecisionTreeClassifier()
dc.fit(X_train,y_train)
plt.figure(figsize=(16,9))
tree.plot_tree(dc,filled=True,class_names=['Not_placed','Placed'],feature_names=train.columns)
# Out:
# [Text(379.43999999999994, 462.06, 'SSC_p <= 59.98\ngini = 0.417\nsamples = 172\nvalue = [51, 121]\nclass = Placed'),
#  Text(142.84799999999998, 407.70000000000005, 'High School_p <= 58.5\ngini = 0.343\nsamples = 41\nvalue = [32, 9]\nclass = Not_placed'),
#  Text(107.136, 353.34000000000003, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]\nclass = Not_placed'),
#  Text(178.55999999999997, 353.34000000000003, 'High School_p <= 66.29\ngini = 0.483\nsamples = 22\nvalue = [13, 9]\nclass = Not_placed'),
#  Text(142.84799999999998, 298.98, 'Specialisation <= 0.5\ngini = 0.498\nsamples = 17\nvalue = [8, 9]\nclass = Placed'),
#  Text(71.42399999999999, 244.62, 'Degree_p <= 58.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = Placed'),
#  Text(35.711999999999996, 190.26, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not_placed'),
#  Text(107.136, 190.26, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Placed'),
#  Text(214.272, 244.62, 'High School_p <= 61.665\ngini = 0.42\nsamples = 10\nvalue = [7, 3]\nclass = Not_placed'),
#  Text(178.55999999999997, 190.26, 'SSC_p <= 55.04\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Placed'),
#  Text(142.84799999999998, 135.90000000000003, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not_placed'),
#  Text(214.272, 135.90000000000003, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Placed'),
#  Text(249.98399999999998, 190.26, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Not_placed'),
#  Text(214.272, 298.98, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Not_placed'),
#  Text(616.0319999999999, 407.70000000000005, 'Degree_p <= 65.8\ngini = 0.248\nsamples = 131\nvalue = [19, 112]\nclass = Placed'),
#  Text(517.824, 353.34000000000003, 'Work Experience <= 0.5\ngini = 0.435\nsamples = 47\nvalue = [15, 32]\nclass = Placed'),
#  Text(482.11199999999997, 298.98, 'High School_p <= 72.24\ngini = 0.499\nsamples = 31\nvalue = [15, 16]\nclass = Placed'),
#  Text(446.4, 244.62, 'MBA_p <= 57.675\ngini = 0.48\nsamples = 25\nvalue = [15, 10]\nclass = Not_placed'),
#  Text(321.40799999999996, 190.26, 'Degree_p <= 53.0\ngini = 0.375\nsamples = 8\nvalue = [2, 6]\nclass = Placed'),
#  Text(285.69599999999997, 135.90000000000003, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not_placed'),
#  Text(357.11999999999995, 135.90000000000003, 'MBA_p <= 51.965\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = Placed'),
#  Text(321.40799999999996, 81.54000000000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not_placed'),
#  Text(392.83199999999994, 81.54000000000002, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Placed'),
#  Text(571.3919999999999, 190.26, 'SSC_p <= 72.445\ngini = 0.36\nsamples = 17\nvalue = [13, 4]\nclass = Not_placed'),
#  Text(499.96799999999996, 135.90000000000003, 'MBA_p <= 65.305\ngini = 0.245\nsamples = 14\nvalue = [12, 2]\nclass = Not_placed'),
#  Text(464.256, 81.54000000000002, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = Not_placed'),
#  Text(535.68, 81.54000000000002, 'MBA_p <= 67.955\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Not_placed'),
#  Text(499.96799999999996, 27.180000000000007, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Placed'),
#  Text(571.3919999999999, 27.180000000000007, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not_placed'),
#  Text(642.8159999999999, 135.90000000000003, 'Degree_p <= 63.1\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Placed'),
#  Text(607.1039999999999, 81.54000000000002, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Placed'),
#  Text(678.5279999999999, 81.54000000000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not_placed'),
#  Text(517.824, 244.62, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Placed'),
#  Text(553.536, 298.98, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]\nclass = Placed'),
#  Text(714.2399999999999, 353.34000000000003, 'High School_p <= 50.0\ngini = 0.091\nsamples = 84\nvalue = [4, 80]\nclass = Placed'),
#  Text(678.5279999999999, 298.98, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not_placed'),
#  Text(749.9519999999999, 298.98, 'Techinal Degree <= 1.5\ngini = 0.07\nsamples = 83\nvalue = [3, 80]\nclass = Placed'),
#  Text(714.2399999999999, 244.62, 'gini = 0.0\nsamples = 62\nvalue = [0, 62]\nclass = Placed'),
#  Text(785.6639999999999, 244.62, 'SSC_p <= 69.4\ngini = 0.245\nsamples = 21\nvalue = [3, 18]\nclass = Placed'),
#  Text(749.9519999999999, 190.26, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not_placed'),
#  Text(821.3759999999999, 190.26, 'SSC_p <= 76.25\ngini = 0.1\nsamples = 19\nvalue = [1, 18]\nclass = Placed'),
#  Text(785.6639999999999, 135.90000000000003, 'SSC_p <= 75.7\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = Placed'),
#  Text(749.9519999999999, 81.54000000000002, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Placed'),
#  Text(821.3759999999999, 81.54000000000002, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not_placed'),
#  Text(857.088, 135.90000000000003, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]\nclass = Placed')]

# %%
costpath = dc.cost_complexity_pruning_path(train,test)
ccp_alpha,impurities = costpath.ccp_alphas,costpath.impurities

# %%
modellist = []
for alpha in ccp_alpha:
    dc = DecisionTreeClassifier(ccp_alpha=alpha)
    dc.fit(X_train,y_train)
    modellist.append(dc)

# %%
train_score = [clf.score(X_train,y_train) for clf in modellist]
test_score = [clf.score(X_test,y_test) for clf in modellist]

plt.xlabel('alpha_value')
plt.ylabel('accuracy')
plt.plot(ccp_alpha,train_score,label = 'train_score',marker = '+',color = 'magenta')
plt.plot(ccp_alpha,test_score,label = 'test_score',marker = '*',color = 'red')
plt.legend()
plt.show()

# %%
dc = DecisionTreeClassifier(ccp_alpha=0.0195)
dc.fit(X_train,y_train)
plt.figure(figsize=(15,7))
tree.plot_tree(dc,filled=True,class_names=['Not_placed','Placed'],feature_names=train.columns)
# Out:
# [Text(418.5, 342.46799999999996, 'SSC_p <= 59.98\ngini = 0.417\nsamples = 172\nvalue = [51, 121]\nclass = Placed'),
#  Text(209.25, 266.364, 'High School_p <= 58.5\ngini = 0.343\nsamples = 41\nvalue = [32, 9]\nclass = Not_placed'),
#  Text(104.625, 190.26, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]\nclass = Not_placed'),
#  Text(313.875, 190.26, 'gini = 0.483\nsamples = 22\nvalue = [13, 9]\nclass = Not_placed'),
#  Text(627.75, 266.364, 'Degree_p <= 65.8\ngini = 0.248\nsamples = 131\nvalue = [19, 112]\nclass = Placed'),
#  Text(523.125, 190.26, 'Work Experience <= 0.5\ngini = 0.435\nsamples = 47\nvalue = [15, 32]\nclass = Placed'),
#  Text(418.5, 114.156, 'High School_p <= 72.24\ngini = 0.499\nsamples = 31\nvalue = [15, 16]\nclass = Placed'),
#  Text(313.875, 38.051999999999964, 'gini = 0.48\nsamples = 25\nvalue = [15, 10]\nclass = Not_placed'),
#  Text(523.125, 38.051999999999964, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Placed'),
#  Text(627.75, 114.156, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]\nclass = Placed'),
#  Text(732.375, 190.26, 'gini = 0.091\nsamples = 84\nvalue = [4, 80]\nclass = Placed')]

# %% [markdown]
# # Hyperparameter Tuning

# %%
params = {
    'RandomForest':{
        'model': RandomForestClassifier(),
        'params':{
            'n_estimators': [int(x) for x in np.linspace(start=1,stop=1200,num=10)],
            'max_depth':[int(x) for x in np.linspace(start=1,stop=30,num=5)],
            'min_samples_split':[2,5,10,12],
            'min_samples_leaf':[2,5,10,12],
            'max_features':['auto','sqrt'],
            'ccp_alpha':[0.0185,0.0190,0.0195,0.0200],
        }
    },
    
    'logistic':{
        'model':LogisticRegression(),
        'params':{
            'penalty':['l1', 'l2', 'elasticnet'],
            'C':[0.25,0.50,0.75,1.0],
            'tol':[1e-10,1e-5,1e-4,1e-3,0.025,0.25,0.50],
            'solver':['lbfgs','liblinear','saga','newton-cg'],
            'multi_class':['auto', 'ovr', 'multinomial'],
            'max_iter':[int(x) for x in np.linspace(start=1,stop=250,num=10)],
        }
    },
    'D-tree':{
        'model':DecisionTreeClassifier(),
        'params':{
            'criterion':['gini','entropy'],
            'splitter':['best','random'],
            'min_samples_split':[1,2,5,10,12],
            'min_samples_leaf':[1,2,5,10,12],
            'max_features':['auto','sqrt'],
            'ccp_alpha':[0.0185,0.0190,0.0195,0.0200],
        }
    },
    'SVM':{
        'model':SVC(),
        'params':{
            'C':[0.25,0.50,0.75,1.0],
            'tol':[1e-10,1e-5,1e-4,0.025,0.50,0.75],
            'kernel':['linear','poly','sigmoid','rbf'],
            'max_iter':[int(x) for x in np.linspace(start=1,stop=250,num=10)],
        }
    }
}

# %%
scores = []
for model_name,mp in params.items():
    
    clf = RandomizedSearchCV(mp['model'],param_distributions=mp['params'],cv=5,n_iter=10,n_jobs=-1,scoring='accuracy')
    clf.fit(X_train,y_train)
    scores.append({
        'model_name':model_name,
        'best_score':clf.best_score_,
        'best_estimator':clf.best_estimator_
    })
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:231: ConvergenceWarning: Solver terminated early (max_iter=56).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)

# %%
scores_df = pd.DataFrame(data = scores,columns = ['model_name','best_score','best_estimator'])
scores_df.head()
# Out:
#      model_name  best_score                                     best_estimator
# 0  RandomForest    0.830924  (DecisionTreeClassifier(ccp_alpha=0.0185, clas...
# 1      logistic    0.825210  LogisticRegression(C=0.5, class_weight=None, d...
# 2        D-tree    0.784370  DecisionTreeClassifier(ccp_alpha=0.019, class_...
# 3           SVM    0.830420  SVC(C=0.5, break_ties=False, cache_size=200, c...

# %%
scores
# Out:
# [{'best_estimator': RandomForestClassifier(bootstrap=True, ccp_alpha=0.0185, class_weight=None,
#                          criterion='gini', max_depth=30, max_features='sqrt',
#                          max_leaf_nodes=None, max_samples=None,
#                          min_impurity_decrease=0.0, min_impurity_split=None,
#                          min_samples_leaf=10, min_samples_split=5,
#                          min_weight_fraction_leaf=0.0, n_estimators=134,
#                          n_jobs=None, oob_score=False, random_state=None,
#                          verbose=0, warm_start=False),
#   'best_score': 0.8309243697478991,
#   'model_name': 'RandomForest'},
#  {'best_estimator': LogisticRegression(C=0.5, class_weight=None, dual=False, fit_intercept=True,
#                      intercept_scaling=1, l1_ratio=None, max_iter=167,
#                      multi_class='ovr', n_jobs=None, penalty='l2',
#                      random_state=None, solver='saga', tol=0.025, verbose=0,
#                      warm_start=False),
#   'best_score': 0.8252100840336134,
#   'model_name': 'logistic'},
#  {'best_estimator': DecisionTreeClassifier(ccp_alpha=0.019, class_weight=None, criterion='gini',
#                          max_depth=None, max_features='auto', max_leaf_nodes=None,
#                          min_impurity_decrease=0.0, min_impurity_split=None,
#                          min_samples_leaf=2, min_samples_split=2,
#                          min_weight_fraction_leaf=0.0, presort='deprecated',
#                          random_state=None, splitter='random'),
#   'best_score': 0.7843697478991597,
#   'model_name': 'D-tree'},
#  {'best_estimator': SVC(C=0.5, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#       decision_function_shape='ovr', degree=3, gamma='scale', kernel='poly',
#       max_iter=56, probability=False, random_state=None, shrinking=True,
#       tol=1e-10, verbose=False),
#   'best_score': 0.8304201680672267,
#   'model_name': 'SVM'}]

# %%
# random forest model


rf = RandomForestClassifier(ccp_alpha=0.02, max_depth=30, max_features='sqrt',
                         min_samples_leaf=2, min_samples_split=12,
                         n_estimators=267)
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.8837209302325582

# %%
# logistic regression

lr = LogisticRegression(C=0.25, max_iter=111, multi_class='ovr', solver='newton-cg',
                     tol=1e-05)

lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.8604651162790697

# %%
# decision tree

dc = DecisionTreeClassifier(ccp_alpha=0.019, criterion='entropy',
                         max_features='auto', min_samples_leaf=5,
                         min_samples_split=5, splitter='random')
dc.fit(X_train,y_train)
y_pred = dc.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.7906976744186046

# %%
print(metrics.classification_report(y_test,rf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.75      0.83        16
#            1       0.87      0.96      0.91        27
#
#     accuracy                           0.88        43
#    macro avg       0.89      0.86      0.87        43
# weighted avg       0.89      0.88      0.88        43

# %%
cn = metrics.confusion_matrix(y_test,rf.predict(X_test))
sns.heatmap(cn,annot=True,cmap='plasma')

# %% [markdown]
# # Model Testing

# %%
traindata = np.array(train)
predicted = []
for i in range(len(traindata)):
    predicted.append(rf.predict([traindata[i]]))
    
predicted
# Out:
# [array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0])]

# %%
resultdf = train.copy()
resultdf['Actual'] = np.array(test)
resultdf['Predicted'] = np.array(predicted)
resultdf.head()
# Out:
#    Techinal Degree  Gender  Specialisation  ...  MBA_p  Actual  Predicted
# 0                2       1               1  ...  58.80       1          1
# 1                2       1               0  ...  66.28       1          1
# 2                0       1               0  ...  57.80       1          1
# 3                2       1               1  ...  59.43       0          0
# 4                0       1               0  ...  55.50       1          1
#
# [5 rows x 10 columns]

# %%
resultdf['Actual'].value_counts()
# Out:
# 1    148
# 0     67
# Name: Actual, dtype: int64

# %%
resultdf['Predicted'].value_counts()
# Out:
# 1    164
# 0     51
# Name: Predicted, dtype: int64

# %%
getmappings
# Out:
# {'degree_t': {'Comm&Mgmt': 0, 'Others': 1, 'Sci&Tech': 2},
#  'gender': {'F': 0, 'M': 1},
#  'hsc_b': {'Central': 0, 'Others': 1},
#  'hsc_s': {'Arts': 0, 'Commerce': 1, 'Science': 2},
#  'specialisation': {'Mkt&Fin': 0, 'Mkt&HR': 1},
#  'ssc_b': {'Central': 0, 'Others': 1},
#  'status': {'Not Placed': 0, 'Placed': 1},
#  'workex': {'No': 0, 'Yes': 1}}

# %% [markdown]
# ### Predicted Probability

# %%
traindata = np.array(train)
predicted = []
for i in range(len(traindata)):
    predicted.append(rf.predict_proba([traindata[i]]))
    
predicted
# Out:
# [array([[0.31574103, 0.68425897]]),
#  array([[0.06523328, 0.93476672]]),
#  array([[0.25099298, 0.74900702]]),
#  array([[0.85621805, 0.14378195]]),
#  array([[0.07050358, 0.92949642]]),
#  array([[0.70246742, 0.29753258]]),
#  array([[0.70664079, 0.29335921]]),
#  array([[0.08193171, 0.91806829]]),
#  array([[0.07016304, 0.92983696]]),
#  array([[0.58294912, 0.41705088]]),
#  array([[0.44047866, 0.55952134]]),
#  array([[0.07355334, 0.92644666]]),
#  array([[0.79187642, 0.20812358]]),
#  array([[0.25291943, 0.74708057]]),
#  array([[0.69088542, 0.30911458]]),
#  array([[0.08629617, 0.91370383]]),
#  array([[0.11938704, 0.88061296]]),
#  array([[0.63114781, 0.36885219]]),
#  array([[0.4703673, 0.5296327]]),
#  array([[0.11537889, 0.88462111]]),
#  array([[0.14335085, 0.85664915]]),
#  array([[0.07329836, 0.92670164]]),
#  array([[0.24544946, 0.75455054]]),
#  array([[0.14719504, 0.85280496]]),
#  array([[0.07912955, 0.92087045]]),
#  array([[0.7713374, 0.2286626]]),
#  array([[0.06265132, 0.93734868]]),
#  array([[0.13589253, 0.86410747]]),
#  array([[0.06234605, 0.93765395]]),
#  array([[0.51758118, 0.48241882]]),
#  array([[0.1199997, 0.8800003]]),
#  array([[0.56979573, 0.43020427]]),
#  array([[0.16867649, 0.83132351]]),
#  array([[0.07741189, 0.92258811]]),
#  array([[0.73758124, 0.26241876]]),
#  array([[0.11663444, 0.88336556]]),
#  array([[0.85452191, 0.14547809]]),
#  array([[0.15893207, 0.84106793]]),
#  array([[0.14061308, 0.85938692]]),
#  array([[0.21625909, 0.78374091]]),
#  array([[0.07550445, 0.92449555]]),
#  array([[0.21835136, 0.78164864]]),
#  array([[0.80321185, 0.19678815]]),
#  array([[0.08379666, 0.91620334]]),
#  array([[0.06360208, 0.93639792]]),
#  array([[0.20300181, 0.79699819]]),
#  array([[0.27081582, 0.72918418]]),
#  array([[0.24626034, 0.75373966]]),
#  array([[0.1435795, 0.8564205]]),
#  array([[0.83766466, 0.16233534]]),
#  array([[0.08960904, 0.91039096]]),
#  array([[0.74135049, 0.25864951]]),
#  array([[0.87094997, 0.12905003]]),
#  array([[0.11973021, 0.88026979]]),
#  array([[0.15179084, 0.84820916]]),
#  array([[0.29361238, 0.70638762]]),
#  array([[0.35083568, 0.64916432]]),
#  array([[0.08689727, 0.91310273]]),
#  array([[0.08468188, 0.91531812]]),
#  array([[0.42647059, 0.57352941]]),
#  array([[0.0661932, 0.9338068]]),
#  array([[0.07122229, 0.92877771]]),
#  array([[0.09615606, 0.90384394]]),
#  array([[0.42047506, 0.57952494]]),
#  array([[0.0711294, 0.9288706]]),
#  array([[0.85371085, 0.14628915]]),
#  array([[0.08447227, 0.91552773]]),
#  array([[0.0703494, 0.9296506]]),
#  array([[0.48415053, 0.51584947]]),
#  array([[0.07023498, 0.92976502]]),
#  array([[0.24644374, 0.75355626]]),
#  array([[0.0853118, 0.9146882]]),
#  array([[0.08233281, 0.91766719]]),
#  array([[0.08346274, 0.91653726]]),
#  array([[0.28319211, 0.71680789]]),
#  array([[0.40177035, 0.59822965]]),
#  array([[0.12508237, 0.87491763]]),
#  array([[0.15128065, 0.84871935]]),
#  array([[0.15717691, 0.84282309]]),
#  array([[0.31233067, 0.68766933]]),
#  array([[0.13411057, 0.86588943]]),
#  array([[0.08643436, 0.91356564]]),
#  array([[0.10955213, 0.89044787]]),
#  array([[0.06785097, 0.93214903]]),
#  array([[0.08340644, 0.91659356]]),
#  array([[0.06991444, 0.93008556]]),
#  array([[0.29582603, 0.70417397]]),
#  array([[0.82756184, 0.17243816]]),
#  array([[0.20959472, 0.79040528]]),
#  array([[0.08904456, 0.91095544]]),
#  array([[0.07546956, 0.92453044]]),
#  array([[0.84528861, 0.15471139]]),
#  array([[0.15820489, 0.84179511]]),
#  array([[0.72480628, 0.27519372]]),
#  array([[0.38518364, 0.61481636]]),
#  array([[0.08505402, 0.91494598]]),
#  array([[0.0711755, 0.9288245]]),
#  array([[0.39652832, 0.60347168]]),
#  array([[0.1733354, 0.8266646]]),
#  array([[0.58858107, 0.41141893]]),
#  array([[0.74620541, 0.25379459]]),
#  array([[0.11622006, 0.88377994]]),
#  array([[0.07160618, 0.92839382]]),
#  array([[0.0901792, 0.9098208]]),
#  array([[0.17494008, 0.82505992]]),
#  array([[0.58706084, 0.41293916]]),
#  array([[0.65160122, 0.34839878]]),
#  array([[0.09186417, 0.90813583]]),
#  array([[0.11691946, 0.88308054]]),
#  array([[0.55909358, 0.44090642]]),
#  array([[0.14690485, 0.85309515]]),
#  array([[0.86232122, 0.13767878]]),
#  array([[0.51445001, 0.48554999]]),
#  array([[0.07269078, 0.92730922]]),
#  array([[0.09399604, 0.90600396]]),
#  array([[0.09725497, 0.90274503]]),
#  array([[0.07627025, 0.92372975]]),
#  array([[0.08040664, 0.91959336]]),
#  array([[0.08990053, 0.91009947]]),
#  array([[0.17112941, 0.82887059]]),
#  array([[0.82531717, 0.17468283]]),
#  array([[0.18031701, 0.81968299]]),
#  array([[0.09497586, 0.90502414]]),
#  array([[0.09958846, 0.90041154]]),
#  array([[0.19035073, 0.80964927]]),
#  array([[0.07532559, 0.92467441]]),
#  array([[0.10130541, 0.89869459]]),
#  array([[0.12918029, 0.87081971]]),
#  array([[0.09285141, 0.90714859]]),
#  array([[0.06366412, 0.93633588]]),
#  array([[0.4551129, 0.5448871]]),
#  array([[0.23714503, 0.76285497]]),
#  array([[0.15177881, 0.84822119]]),
#  array([[0.09303053, 0.90696947]]),
#  array([[0.06841096, 0.93158904]]),
#  array([[0.2316018, 0.7683982]]),
#  array([[0.65712265, 0.34287735]]),
#  array([[0.12789643, 0.87210357]]),
#  array([[0.10020642, 0.89979358]]),
#  array([[0.15319112, 0.84680888]]),
#  array([[0.07453015, 0.92546985]]),
#  array([[0.46260047, 0.53739953]]),
#  array([[0.07483935, 0.92516065]]),
#  array([[0.07788704, 0.92211296]]),
#  array([[0.84109909, 0.15890091]]),
#  array([[0.12997223, 0.87002777]]),
#  array([[0.15110286, 0.84889714]]),
#  array([[0.16415254, 0.83584746]]),
#  array([[0.25150112, 0.74849888]]),
#  array([[0.70470698, 0.29529302]]),
#  array([[0.2052718, 0.7947282]]),
#  array([[0.09151306, 0.90848694]]),
#  array([[0.1132589, 0.8867411]]),
#  array([[0.51849913, 0.48150087]]),
#  array([[0.48751911, 0.51248089]]),
#  array([[0.58914703, 0.41085297]]),
#  array([[0.15737575, 0.84262425]]),
#  array([[0.30194577, 0.69805423]]),
#  array([[0.3202769, 0.6797231]]),
#  array([[0.87158507, 0.12841493]]),
#  array([[0.14568538, 0.85431462]]),
#  array([[0.84798902, 0.15201098]]),
#  array([[0.06236978, 0.93763022]]),
#  array([[0.32931098, 0.67068902]]),
#  array([[0.25074413, 0.74925587]]),
#  array([[0.13190846, 0.86809154]]),
#  array([[0.30742583, 0.69257417]]),
#  array([[0.14867494, 0.85132506]]),
#  array([[0.77818043, 0.22181957]]),
#  array([[0.79634662, 0.20365338]]),
#  array([[0.53871966, 0.46128034]]),
#  array([[0.06236978, 0.93763022]]),
#  array([[0.2830537, 0.7169463]]),
#  array([[0.86876074, 0.13123926]]),
#  array([[0.29575735, 0.70424265]]),
#  array([[0.43307586, 0.56692414]]),
#  array([[0.60623424, 0.39376576]]),
#  array([[0.06407897, 0.93592103]]),
#  array([[0.32786548, 0.67213452]]),
#  array([[0.3753357, 0.6246643]]),
#  array([[0.14912804, 0.85087196]]),
#  array([[0.50675492, 0.49324508]]),
#  array([[0.61479594, 0.38520406]]),
#  array([[0.09010173, 0.90989827]]),
#  array([[0.66334452, 0.33665548]]),
#  array([[0.0990736, 0.9009264]]),
#  array([[0.71312489, 0.28687511]]),
#  array([[0.07131938, 0.92868062]]),
#  array([[0.63515897, 0.36484103]]),
#  array([[0.46662294, 0.53337706]]),
#  array([[0.44641522, 0.55358478]]),
#  array([[0.11907406, 0.88092594]]),
#  array([[0.14292189, 0.85707811]]),
#  array([[0.34380519, 0.65619481]]),
#  array([[0.8343386, 0.1656614]]),
#  array([[0.08287713, 0.91712287]]),
#  array([[0.07454151, 0.92545849]]),
#  array([[0.32100825, 0.67899175]]),
#  array([[0.35132376, 0.64867624]]),
#  array([[0.30984099, 0.69015901]]),
#  array([[0.22608483, 0.77391517]]),
#  array([[0.70652482, 0.29347518]]),
#  array([[0.18443037, 0.81556963]]),
#  array([[0.64102961, 0.35897039]]),
#  array([[0.0671743, 0.9328257]]),
#  array([[0.24117273, 0.75882727]]),
#  array([[0.8159934, 0.1840066]]),
#  array([[0.17214587, 0.82785413]]),
#  array([[0.68824306, 0.31175694]]),
#  array([[0.20331054, 0.79668946]]),
#  array([[0.07428505, 0.92571495]]),
#  array([[0.25277484, 0.74722516]]),
#  array([[0.08024839, 0.91975161]]),
#  array([[0.32287571, 0.67712429]]),
#  array([[0.57494245, 0.42505755]])]

# %%
predicted[0][0],predicted[0][0][0],predicted[0][0][1]
# Out:
# (array([0.31574103, 0.68425897]), 0.31574102630539114, 0.6842589736946093)

# %%
resultdf['Prob_not_getting_placed'] = np.array([predicted[i][0][0] for i in range(len(predicted))])
resultdf['Prob_getting_placed'] = np.array([predicted[i][0][1] for i in range(len(predicted))])
resultdf
# Out:
#      Techinal Degree  Gender  ...  Prob_not_getting_placed  Prob_getting_placed
# 0                  2       1  ...                 0.315741             0.684259
# 1                  2       1  ...                 0.065233             0.934767
# 2                  0       1  ...                 0.250993             0.749007
# 3                  2       1  ...                 0.856218             0.143782
# 4                  0       1  ...                 0.070504             0.929496
# ..               ...     ...  ...                      ...                  ...
# 210                0       1  ...                 0.074285             0.925715
# 211                2       1  ...                 0.252775             0.747225
# 212                0       1  ...                 0.080248             0.919752
# 213                0       0  ...                 0.322876             0.677124
# 214                0       1  ...                 0.574942             0.425058
#
# [215 rows x 12 columns]

# %%
# saving the model

import pickle
file = open('campusplacementpredictor.pkl','wb')
pickle.dump(rf,file)
file.close()

# %% [markdown]
# ### Conclusions
#
#  + Random Forest model gave the best results with decent accuracy of 85%+
